# %% [markdown]
# # Data Cleanup
# Now let's begin the process of cleaning up the string data we scraped from Glassdoor.

# %%
# libraries needed
import pandas as pd
import numpy as np
from datetime import datetime

pd.set_option('display.max_rows', 100)
pd.options.mode.chained_assignment = None

# %%
# get some information on the saved data
file_name = r"C:\Users\Tineash\Projects\Glassdoor_webscraper\Data\AV_eng_data.csv" # enter the filepath between the quotes
data = pd.read_csv(file_name)
data.head(10)
# Out:
#                                         Job Title Salary Minimum  \
# 0             Audio Visual System Design Engineer          $61K
# 1                    Audio Visual Design Engineer          $85K
# 2             Audio Visual Systems Field Engineer          $48K
# 3               (NY) Audio/Visual Design Engineer          $50K
# 4                   Audio Visual Systems Engineer            NaN
# 5                           Audio Visual Engineer          $44K
# 6                    Audio Visual Design Engineer          $65K
# 7          Audio Visual Design Engineer/Estimator          $85K
# 8                   Audio Visual Systems Engineer            NaN
# 9  Pre-Sales Design Engineer, Audio Visual Remote          $56K
#
#   Salary Maximum      Salary Average  Rating  \
# 0          $100K  $80,500 /yr (est.)     NaN
# 1          $110K  $97,500 /yr (est.)     4.3
# 2           $83K  $63,005 /yr (est.)     4.3
# 3           $98K  $69,978 /yr (est.)     3.8
# 4            NaN                 NaN     NaN
# 5          $103K  $67,259 /yr (est.)     3.1
# 6           $90K  $77,500 /yr (est.)     NaN
# 7          $105K  $95,000 /yr (est.)     3.2
# 8            NaN                 NaN     NaN
# 9          $102K  $75,493 /yr (est.)     3.6
#
#                                     Company Name             Location  \
# 0                                            CCS           Denver, CO
# 1                                   AV-Worx\n4.3  West Palm Beach, FL
# 2                             System Source\n4.3      Hunt Valley, MD
# 3                         A-V Services Inc.\n3.8         New York, NY
# 4               Camera Corner / Connecting Point        Green Bay, WI
# 5                          JVN Systems Inc.\n3.1        Deer Park, NY
# 6                      Technology Providers Inc.          Gilbert, AZ
# 7            Network Cabling Services (NCS)\n3.2           Dallas, TX
# 8  ACP CreativIT dba Arlington Computer Products    Buffalo Grove, IL
# 9                          Johnson Controls\n3.6          Roswell, GA
#
#                    Size  Founded  Type of ownership  \
# 0                   NaN      NaN                NaN
# 1     1 to 50 Employees   2014.0  Company - Private
# 2   51 to 200 Employees   1981.0  Company - Private
# 3  201 to 500 Employees   1960.0  Company - Private
# 4                   NaN      NaN                NaN
# 5     1 to 50 Employees      NaN  Company - Private
# 6                   NaN      NaN                NaN
# 7  201 to 500 Employees      NaN  Company - Private
# 8                   NaN      NaN                NaN
# 9      10000+ Employees   1885.0   Company - Public
#
#                                   Industry                   Sector  \
# 0                                      NaN                      NaN
# 1                      Business Consulting  Management & Consulting
# 2  Information Technology Support Services   Information Technology
# 3              Telecommunications Services       Telecommunications
# 4                                      NaN                      NaN
# 5                                      NaN                      NaN
# 6                                      NaN                      NaN
# 7              Telecommunications Services       Telecommunications
# 8                                      NaN                      NaN
# 9                  Machinery Manufacturing            Manufacturing
#
#                     Revenue
# 0                       NaN
# 1   $5 to $10 million (USD)
# 2  $10 to $25 million (USD)
# 3  Unknown / Non-Applicable
# 4                       NaN
# 5   $5 to $10 million (USD)
# 6                       NaN
# 7  Unknown / Non-Applicable
# 8                       NaN
# 9        $10+ billion (USD)

# %%
#We see some NaN values, so let's confirm they are recognized as nulls
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          1000 non-null   object
#  1   Salary Minimum     816 non-null    object
#  2   Salary Maximum     816 non-null    object
#  3   Salary Average     848 non-null    object
#  4   Rating             817 non-null    float64
#  5   Company Name       1000 non-null   object
#  6   Location           1000 non-null   object
#  7   Size               857 non-null    object
#  8   Founded            646 non-null    float64
#  9   Type of ownership  857 non-null    object
#  10  Industry           712 non-null    object
#  11  Sector             712 non-null    object
#  12  Revenue            857 non-null    object
# dtypes: float64(2), object(11)
# memory usage: 101.7+ KB

# %% [markdown]
# Above, we can see that some columns are fully populated, such as 'Job Title', but others have nulls. I do see some black values where there should be NaNs, so I will run through the document and replace empty cells with NaN. I will want to convert the year founded into years existing. I have to clean up some duplicates I see, convert the salary to a float and remove non numeric characters, and clean up some trailing characters at the end of the company names (/n#). It would be useful to have the location be split into city and states. I may want to clean up the string for type of ownership into just Private vs Public, but I'll run through it to confirm. Finally, I will have to review the revenue data and convert the Unknown/NA into nulls, then determine if the information can be used. **A significant and fun list!**

# %%
#Replace empty cells with NaN
#r = raw string. ^ = start of line $ = end of line \s* = any length of string (accounts for whitespace)
data = data.replace(r'^\s*$', np.nan, regex=True) # we use regex to check the cell expression and see if it matches the input
data.head(10)
# Out:
#                                         Job Title Salary Minimum  \
# 0             Audio Visual System Design Engineer          $61K
# 1                    Audio Visual Design Engineer          $85K
# 2             Audio Visual Systems Field Engineer          $48K
# 3               (NY) Audio/Visual Design Engineer          $50K
# 4                   Audio Visual Systems Engineer            NaN
# 5                           Audio Visual Engineer          $44K
# 6                    Audio Visual Design Engineer          $65K
# 7          Audio Visual Design Engineer/Estimator          $85K
# 8                   Audio Visual Systems Engineer            NaN
# 9  Pre-Sales Design Engineer, Audio Visual Remote          $56K
#
#   Salary Maximum      Salary Average  Rating  \
# 0          $100K  $80,500 /yr (est.)     NaN
# 1          $110K  $97,500 /yr (est.)     4.3
# 2           $83K  $63,005 /yr (est.)     4.3
# 3           $98K  $69,978 /yr (est.)     3.8
# 4            NaN                 NaN     NaN
# 5          $103K  $67,259 /yr (est.)     3.1
# 6           $90K  $77,500 /yr (est.)     NaN
# 7          $105K  $95,000 /yr (est.)     3.2
# 8            NaN                 NaN     NaN
# 9          $102K  $75,493 /yr (est.)     3.6
#
#                                     Company Name             Location  \
# 0                                            CCS           Denver, CO
# 1                                   AV-Worx\n4.3  West Palm Beach, FL
# 2                             System Source\n4.3      Hunt Valley, MD
# 3                         A-V Services Inc.\n3.8         New York, NY
# 4               Camera Corner / Connecting Point        Green Bay, WI
# 5                          JVN Systems Inc.\n3.1        Deer Park, NY
# 6                      Technology Providers Inc.          Gilbert, AZ
# 7            Network Cabling Services (NCS)\n3.2           Dallas, TX
# 8  ACP CreativIT dba Arlington Computer Products    Buffalo Grove, IL
# 9                          Johnson Controls\n3.6          Roswell, GA
#
#                    Size  Founded  Type of ownership  \
# 0                   NaN      NaN                NaN
# 1     1 to 50 Employees   2014.0  Company - Private
# 2   51 to 200 Employees   1981.0  Company - Private
# 3  201 to 500 Employees   1960.0  Company - Private
# 4                   NaN      NaN                NaN
# 5     1 to 50 Employees      NaN  Company - Private
# 6                   NaN      NaN                NaN
# 7  201 to 500 Employees      NaN  Company - Private
# 8                   NaN      NaN                NaN
# 9      10000+ Employees   1885.0   Company - Public
#
#                                   Industry                   Sector  \
# 0                                      NaN                      NaN
# 1                      Business Consulting  Management & Consulting
# 2  Information Technology Support Services   Information Technology
# 3              Telecommunications Services       Telecommunications
# 4                                      NaN                      NaN
# 5                                      NaN                      NaN
# 6                                      NaN                      NaN
# 7              Telecommunications Services       Telecommunications
# 8                                      NaN                      NaN
# 9                  Machinery Manufacturing            Manufacturing
#
#                     Revenue
# 0                       NaN
# 1   $5 to $10 million (USD)
# 2  $10 to $25 million (USD)
# 3  Unknown / Non-Applicable
# 4                       NaN
# 5   $5 to $10 million (USD)
# 6                       NaN
# 7  Unknown / Non-Applicable
# 8                       NaN
# 9        $10+ billion (USD)

# %%
# checking columns for nulls
data.isnull().sum()
# Out:
# Job Title              0
# Salary Minimum       184
# Salary Maximum       184
# Salary Average       152
# Rating               183
# Company Name           0
# Location               0
# Size                 143
# Founded              354
# Type of ownership    143
# Industry             288
# Sector               288
# Revenue              143
# dtype: int64

# %%
#Remove features where the salary is null,since that doesnt help us
data_cleaned = data.dropna(axis=0,subset=['Salary Average', 'Salary Minimum'])
data_cleaned.isnull().sum()
# Out:
# Job Title              0
# Salary Minimum         0
# Salary Maximum         0
# Salary Average         0
# Rating               131
# Company Name           0
# Location               0
# Size                  91
# Founded              269
# Type of ownership     91
# Industry             204
# Sector               204
# Revenue               91
# dtype: int64

# %%
# separate hourly rows from salary rows
data_cleaned = pd.DataFrame(data = data_cleaned) # convert the slice to a pandas dataframe to work with it
data_cleaned['Average Hourly Rate'] = data_cleaned["Salary Average"].apply(lambda x: 1 if '/hr' in x.lower() else 0)
data_cleaned = data_cleaned.reset_index(drop=True)
data_cleaned.head(20)
# Out:
#                                          Job Title Salary Minimum  \
# 0              Audio Visual System Design Engineer          $61K
# 1                     Audio Visual Design Engineer          $85K
# 2              Audio Visual Systems Field Engineer          $48K
# 3                (NY) Audio/Visual Design Engineer          $50K
# 4                            Audio Visual Engineer          $44K
# 5                     Audio Visual Design Engineer          $65K
# 6           Audio Visual Design Engineer/Estimator          $85K
# 7   Pre-Sales Design Engineer, Audio Visual Remote          $56K
# 8                      Audio Visual Sales Engineer          $70K
# 9               Audio Visual Design Sales Engineer          $65K
# 10                     Audio Visual Field Engineer     $20.00 /hr
# 11     Systems Engineer - Audio/Visual Integration          $49K
# 12                   Audio Visual Systems Engineer          $70K
# 13                      Audio Visual (AV) Engineer     $39.59 /hr
# 14         Senior Associate, Audio-Visual Engineer         $100K
# 15                    Audio Visual Engineer - Poly          $54K
# 16                           Audio Visual Engineer     $30.00 /hr
# 17                     Audio Visual Sales Engineer          $80K
# 18            Senior Audio Visual Systems Engineer          $52K
# 19                                  Audio Engineer          $47K
#
#    Salary Maximum       Salary Average  Rating  \
# 0           $100K   $80,500 /yr (est.)     NaN
# 1           $110K   $97,500 /yr (est.)     4.3
# 2            $83K   $63,005 /yr (est.)     4.3
# 3            $98K   $69,978 /yr (est.)     3.8
# 4           $103K   $67,259 /yr (est.)     3.1
# 5            $90K   $77,500 /yr (est.)     NaN
# 6           $105K   $95,000 /yr (est.)     3.2
# 7           $102K   $75,493 /yr (est.)     3.6
# 8            $80K   $75,000 /yr (est.)     NaN
# 9            $85K   $75,000 /yr (est.)     3.6
# 10         $40.00    $30.00 /hr (est.)     NaN
# 11          $108K   $72,437 /yr (est.)     2.9
# 12           $70K   $70,000 /yr (est.)     4.2
# 13         $45.84    $42.71 /hr (est.)     3.9
# 14          $125K  $112,500 /yr (est.)     3.8
# 15          $122K   $81,352 /yr (est.)     3.8
# 16         $37.00    $33.50 /hr (est.)     4.0
# 17          $120K  $100,000 /yr (est.)     NaN
# 18           $96K   $70,828 /yr (est.)     4.3
# 19           $93K   $65,776 /yr (est.)     4.1
#
#                            Company Name              Location  \
# 0                                   CCS            Denver, CO
# 1                          AV-Worx\n4.3   West Palm Beach, FL
# 2                    System Source\n4.3       Hunt Valley, MD
# 3                A-V Services Inc.\n3.8          New York, NY
# 4                 JVN Systems Inc.\n3.1         Deer Park, NY
# 5             Technology Providers Inc.           Gilbert, AZ
# 6   Network Cabling Services (NCS)\n3.2            Dallas, TX
# 7                 Johnson Controls\n3.6           Roswell, GA
# 8                                 Vario                Remote
# 9       Spectra Audio Design Group\n3.6          New York, NY
# 10                        Vistacom, Inc          Pennsylvania
# 11                           Bluum\n2.9        Saint Paul, MN
# 12                 The Mom Project\n4.2          New York, NY
# 13                     Robert Half\n3.9        Richardson, TX
# 14          TM Technology Partners\n3.8                Remote
# 15                  American Water\n3.8            Camden, NJ
# 16                  Infomatics Inc\n4.0  Farmington Hills, MI
# 17                Commercial Technology           Clifton, NJ
# 18           POWER Engineers, Inc.\n4.3             Boise, ID
# 19                  Cato Institute\n4.1        Washington, DC
#
#                        Size  Founded       Type of ownership  \
# 0                       NaN      NaN                     NaN
# 1         1 to 50 Employees   2014.0       Company - Private
# 2       51 to 200 Employees   1981.0       Company - Private
# 3      201 to 500 Employees   1960.0       Company - Private
# 4         1 to 50 Employees      NaN       Company - Private
# 5                       NaN      NaN                     NaN
# 6      201 to 500 Employees      NaN       Company - Private
# 7          10000+ Employees   1885.0        Company - Public
# 8                       NaN      NaN                     NaN
# 9         1 to 50 Employees      NaN       Company - Private
# 10                      NaN      NaN                     NaN
# 11    501 to 1000 Employees   1946.0       Company - Private
# 12      51 to 200 Employees   2016.0       Company - Private
# 13         10000+ Employees   1948.0        Company - Public
# 14        1 to 50 Employees      NaN       Company - Private
# 15  5001 to 10000 Employees   1886.0        Company - Public
# 16      51 to 200 Employees   1998.0       Company - Private
# 17                      NaN      NaN                     NaN
# 18   1001 to 5000 Employees   1976.0       Company - Private
# 19      51 to 200 Employees   1976.0  Nonprofit Organization
#
#                                    Industry                      Sector  \
# 0                                       NaN                         NaN
# 1                       Business Consulting     Management & Consulting
# 2   Information Technology Support Services      Information Technology
# 3               Telecommunications Services          Telecommunications
# 4                                       NaN                         NaN
# 5                                       NaN                         NaN
# 6               Telecommunications Services          Telecommunications
# 7                   Machinery Manufacturing               Manufacturing
# 8                                       NaN                         NaN
# 9            Advertising & Public Relations       Media & Communication
# 10                                      NaN                         NaN
# 11  Information Technology Support Services      Information Technology
# 12                            HR Consulting  Human Resources & Staffing
# 13                            HR Consulting  Human Resources & Staffing
# 14                      Business Consulting     Management & Consulting
# 15                       Energy & Utilities  Energy, Mining & Utilities
# 16  Information Technology Support Services      Information Technology
# 17                                      NaN                         NaN
# 18                       Energy & Utilities  Energy, Mining & Utilities
# 19     Grantmaking & Charitable Foundations             Nonprofit & NGO
#
#                              Revenue  Average Hourly Rate
# 0                                NaN                    0
# 1            $5 to $10 million (USD)                    0
# 2           $10 to $25 million (USD)                    0
# 3           Unknown / Non-Applicable                    0
# 4            $5 to $10 million (USD)                    0
# 5                                NaN                    0
# 6           Unknown / Non-Applicable                    0
# 7                 $10+ billion (USD)                    0
# 8                                NaN                    0
# 9            $5 to $10 million (USD)                    0
# 10                               NaN                    1
# 11          Unknown / Non-Applicable                    0
# 12          Unknown / Non-Applicable                    0
# 13           $5 to $10 billion (USD)                    1
# 14           $5 to $10 million (USD)                    0
# 15            $2 to $5 billion (USD)                    0
# 16          $10 to $25 million (USD)                    1
# 17                               NaN                    0
# 18  $500 million to $1 billion (USD)                    0
# 19          $25 to $50 million (USD)                    0

# %% [markdown]
# We can see that there appears to be average hourly rate data in here. Let's split those out so we can compare the hourly rates to the salary rates givin when we analyze the data.

# %%
#clean up Salary min/max/average strings to only have numeric strings, then convert to float
# remove $, ',',(/yr (est.)

#First, lets clean up the Average Salary
salary_avg = data_cleaned['Salary Average'].apply(lambda x: x.split("/")[0])
salary_avg = salary_avg.apply(lambda x: x.replace('$', '').replace(',',''))
data_cleaned['Salary Average'] = salary_avg

#Now the minimum salary
salary_min = data_cleaned['Salary Minimum'].apply(lambda x:x.replace('$', '').replace('K','').replace('/hr', '').replace('/mo', ''))
data_cleaned['Salary Minimum']=salary_min


#Now the maximum salary
salary_max = data_cleaned['Salary Maximum'].apply(lambda x:x.replace('$', '').replace('K','').replace('/mo', ''))
data_cleaned['Salary Maximum']=salary_max
data_cleaned.tail(10)
# Out:
#                                           Job Title Salary Minimum  \
# 806  Audio Visual Technician (AV) - Santa Clara, CA            44
# 807                    Audio Visual Design Engineer            44
# 808               (NY) Audio/Visual Design Engineer            50
# 809     Systems Engineer - Audio/Visual Integration            63
# 810                     Audio Visual Field Engineer         20.00
# 811                     Audio Visual Field Engineer         20.00
# 812  Pre-Sales Design Engineer, Audio Visual Remote            56
# 813                     Audio Visual Sales Engineer            70
# 814                   Audio Visual Systems Engineer            70
# 815              Lead Audio Visual Field Technician            35
#
#     Salary Maximum Salary Average  Rating                        Company Name  \
# 806             98         65414      3.7                      Black Box\n3.7
# 807             75         57568      3.7  Conference Technologies, Inc.\n3.7
# 808             98         69978      3.8              A-V Services Inc.\n3.8
# 809            130         90706      2.9                          Bluum\n2.9
# 810          40.00         30.00      NaN                       Vistacom, Inc
# 811          40.00         30.00      NaN                       Vistacom, Inc
# 812            102         75493      3.6               Johnson Controls\n3.6
# 813             80         75000      NaN                               Vario
# 814             70         70000      4.2                The Mom Project\n4.2
# 815             76         51724      3.4                            EOS\n3.4
#
#             Location                    Size  Founded  Type of ownership  \
# 806  Santa Clara, CA  1001 to 5000 Employees   1975.0  Company - Private
# 807      Atlanta, GA    201 to 500 Employees   1988.0  Company - Private
# 808     New York, NY    201 to 500 Employees   1960.0  Company - Private
# 809     New York, NY   501 to 1000 Employees   1946.0  Company - Private
# 810     Pennsylvania                     NaN      NaN                NaN
# 811     Pennsylvania                     NaN      NaN                NaN
# 812      Roswell, GA        10000+ Employees   1885.0   Company - Public
# 813           Remote                     NaN      NaN                NaN
# 814     New York, NY     51 to 200 Employees   2016.0  Company - Private
# 815     New York, NY   501 to 1000 Employees   2008.0  Company - Private
#
#                                     Industry                      Sector  \
# 806  Information Technology Support Services      Information Technology
# 807              Telecommunications Services          Telecommunications
# 808              Telecommunications Services          Telecommunications
# 809  Information Technology Support Services      Information Technology
# 810                                      NaN                         NaN
# 811                                      NaN                         NaN
# 812                  Machinery Manufacturing               Manufacturing
# 813                                      NaN                         NaN
# 814                            HR Consulting  Human Resources & Staffing
# 815  Information Technology Support Services      Information Technology
#
#                               Revenue  Average Hourly Rate
# 806  $500 million to $1 billion (USD)                    0
# 807         $50 to $100 million (USD)                    0
# 808          Unknown / Non-Applicable                    0
# 809          Unknown / Non-Applicable                    0
# 810                               NaN                    1
# 811                               NaN                    1
# 812                $10+ billion (USD)                    0
# 813                               NaN                    0
# 814          Unknown / Non-Applicable                    0
# 815          Unknown / Non-Applicable                    0

# %% [markdown]
# Now lets convert the hourly values to salary

# %%
# convert hourly salary to yearly salary
# convert $/hr to $/year and replace cells with the yearly estimate
def hr_to_year(i):
    i = int(float(i)) # convert the string to a float
    i = i*40*52
    #print("A rate of $", i,"/hr will be a salary of $", int(salary),"/yr.")
    return i
data_cleaned["Salary Maximum"] = data_cleaned["Salary Maximum"].astype(str).apply(lambda x: hr_to_year(x)/1000 if x.find('.') != -1 else x)
data_cleaned["Salary Minimum"] = data_cleaned["Salary Minimum"].astype(str).apply(lambda x: hr_to_year(x)/1000 if x.find('.') != -1 else x)
data_cleaned["Converted Salary"] = data_cleaned["Salary Average"].apply(lambda x: hr_to_year(x) if x.find('.') != -1 else x)
data_cleaned[["Salary Average", "Salary Minimum", 'Salary Maximum', "Converted Salary"]].tail(10)
# Out:
#     Salary Average Salary Minimum Salary Maximum Converted Salary
# 806         65414             44              98           65414
# 807         57568             44              75           57568
# 808         69978             50              98           69978
# 809         90706             63             130           90706
# 810         30.00            41.6           83.2            62400
# 811         30.00            41.6           83.2            62400
# 812         75493             56             102           75493
# 813         75000             70              80           75000
# 814         70000             70              70           70000
# 815         51724             35              76           51724

# %% [markdown]
# With the hourly rate converted to yearly salary and a column marking which rows had an hourly value, we can now move on to some simplier tasks, such as converting data types and cleaning up some strings.

# %%
# remove trailing 5 characters from Company Name strings
data_cleaned['Company Name'] = data_cleaned["Company Name"].apply(lambda x: x.split('\n', 1)[0] if x.find('\n') != -1 else x)
data_cleaned['Company Name'].head(15)
# Out:
# 0                                CCS
# 1                            AV-Worx
# 2                      System Source
# 3                  A-V Services Inc.
# 4                   JVN Systems Inc.
# 5          Technology Providers Inc.
# 6     Network Cabling Services (NCS)
# 7                   Johnson Controls
# 8                              Vario
# 9         Spectra Audio Design Group
# 10                     Vistacom, Inc
# 11                             Bluum
# 12                   The Mom Project
# 13                       Robert Half
# 14            TM Technology Partners
# Name: Company Name, dtype: object

# %%
# split location to city and state


#str(string_check.iloc[0]).split(',')[1]
#a = 0
#for i in DA_data_cleaned["Location"]:
#    if ',' in str(DA_data_cleaned["Location"].iloc[i]):
#        DA_data_cleaned["City"] = str(DA_data_cleaned["Location"].iloc[i]).split(',')[0]
#        DA_data_cleaned["State"] = str(DA_data_cleaned["Location"].iloc[i]).split(',')[1]
#        a += 1
#    else:
#        DA_data_cleaned["City"] = "Remote"
#        DA_data_cleaned["State"] = "Remote"
#        a +=1

data_cleaned["City"] = data_cleaned["Location"].apply(lambda x: x.split(', ')[0])
data_cleaned["State"] = data_cleaned["Location"].apply(lambda x: x.split(',')[-1] if x.find(',') != 1 else "Remote") 
data_cleaned["State"] = data_cleaned["State"].apply(lambda x: x.strip() if x.strip().lower() != 'manhattan' else 'NY') # edge case, comment out if needed
data_cleaned["State"] = data_cleaned["State"].apply(lambda x: "PA" if x.strip().lower() == 'pennsylvania' else x)# edge case, comment out if needed
data_cleaned["State"] = data_cleaned["State"].apply(lambda x: "NY" if x.strip().lower() == 'new york state' else x)# edge case, comment out if needed
data_cleaned["State"] = data_cleaned["State"].apply(lambda x: "Remote" if x.strip().lower() == 'united states' else x)# edge case, comment out if needed
data_cleaned['State'].value_counts()
# Out:
# NY        233
# CA         91
# Remote     57
# TX         47
# FL         46
# GA         43
# WA         42
# NJ         32
# ID         30
# DC         29
# PA         29
# MI         29
# MN         20
# CO         19
# HI         17
# AZ         16
# CT         11
# MA          7
# MD          3
# OK          3
# IL          2
# MO          2
# OH          2
# NV          2
# LA          2
# UT          1
# VA          1
# Name: State, dtype: int64

# %%
# convert year founded to years in existance
currentyear = datetime.now().year
data_cleaned['Company Age (years)'] = data_cleaned["Founded"].apply(lambda x:-1 if x==float(np.nan) else currentyear - x)
data_cleaned
# Out:
#                                              Job Title Salary Minimum  \
# 0                  Audio Visual System Design Engineer            61
# 1                         Audio Visual Design Engineer            85
# 2                  Audio Visual Systems Field Engineer            48
# 3                    (NY) Audio/Visual Design Engineer            50
# 4                                Audio Visual Engineer            44
# 5                         Audio Visual Design Engineer            65
# 6               Audio Visual Design Engineer/Estimator            85
# 7       Pre-Sales Design Engineer, Audio Visual Remote            56
# 8                          Audio Visual Sales Engineer            70
# 9                   Audio Visual Design Sales Engineer            65
# 10                         Audio Visual Field Engineer           41.6
# 11         Systems Engineer - Audio/Visual Integration            49
# 12                       Audio Visual Systems Engineer            70
# 13                          Audio Visual (AV) Engineer          81.12
# 14             Senior Associate, Audio-Visual Engineer           100
# 15                        Audio Visual Engineer - Poly            54
# 16                               Audio Visual Engineer           62.4
# 17                         Audio Visual Sales Engineer            80
# 18                Senior Audio Visual Systems Engineer            52
# 19                                      Audio Engineer            47
# 20                Audio Visual Systems Design Engineer            45
# 21   Technical Design Engineer - Audio Visual - $70...            70
# 22                               Audio-Visual Engineer            64
# 23                        Audio Visual Design Engineer            44
# 24                         Audio Visual Sales Engineer            56
# 25                             Audio Visual Technician           41.6
# 26                           Sr. Audio-Visual Engineer           120
# 27                            Technical Sound Designer         106.08
# 28   Senior Service Engineer - Audio-Visual System ...           106
# 29                    Audio Visual Production Engineer            49
# 30                 Senior Audio Visual Design Engineer            77
# 31              Audio Visual Technician (Sr. Engineer)            56
# 32               Sr. Network Technician-Audio Visual 1            35
# 33                 Audio Visual Collaboration Engineer            57
# 34                               Audio Visual Engineer            44
# 35                         Audio Visual Field Engineer            40
# 36                               Audio Visual Engineer            70
# 37   Audio Visual Engineer - Information Technology...            60
# 38                       Audio Visual Systems Engineer            38
# 39                Senior Audio-Visual Systems Engineer            50
# 40                 Sneaky Big Studios - Audio Engineer            40
# 41                               Audio Visual Engineer            60
# 42                     Audio Visual (AV) Post Engineer            39
# 43                          Freelance Audio Engineer I            29
# 44                        Audio Visual Design Engineer            49
# 45                Coordinator and Audio-Video Engineer            42
# 46                      Audio-Visual Engineer Tier III           72.8
# 47                               Audio Visual Engineer            64
# 48                             Audio & Visual Engineer            32
# 49                        Audio Visual Design Engineer            55
# 50                     Audio Visual Technicians Sought            30
# 51                         Audio Visual Field Engineer            60
# 52                         Audio Visual Field Engineer            34
# 53   A/V Project Manager / Systems Design Engineer ...            60
# 54                                   R&D Test Engineer            75
# 55                             Audio Visual Technician          68.64
# 56                          Lead Audio Visual Engineer            74
# 57                                 AV Service Engineer            80
# 58                   Audio / Visual Support Specialist           31.2
# 59   AV Field Engineer/Audio/Video Technician/Audio...            35
# 60   Information Technology Help Desk Support - Up ...            85
# 61   AV Field Engineer/Audio/Video Technician/Audio...            35
# 62                             Audio Visual Technician           62.4
# 63                            Technical Sound Designer         106.08
# 64                            Technical Sound Designer         106.08
# 65   AUDIO VIDEO SYSTEMS ENGINEER/Jr. CRESTRON PROG...            80
# 66              Audio Visual Technician (Sr. Engineer)            56
# 67          Professional Audio-Visual Systems Engineer            47
# 68                      Audio-Visual Engineer Tier III           72.8
# 69                Coordinator and Audio-Video Engineer            42
# 70          Audio Visual Engineer Technical Specialist            97
# 71                   Audio Visual Fabrication Engineer            54
# 72                   Audio Visual Fabrication Engineer            54
# 73                       Audio Visual Project Engineer            64
# 74          Audio Visual Fabrication Engineer – Senior            62
# 75       UC - Audio Visual/Multimedia Engineer Level 2            38
# 76                        Onsite Audio Visual Engineer            43
# 77                        Onsite Audio Visual Engineer            43
# 78                               Audio Visual Engineer            43
# 79                          Lead Audio Visual Engineer            74
# 80                             Audio Visual Technician          58.24
# 81                           Sr. Audio-Visual Engineer           120
# 82                                 AV Systems Engineer          54.08
# 83   Information Technology Help Desk Support - Up ...            85
# 84   AV Field Engineer/Audio/Video Technician/Audio...            35
# 85                                       AV Technician          37.44
# 86                             Audio Visual Technician           62.4
# 87                                         AV Engineer           83.2
# 88   AUDIO VIDEO SYSTEMS ENGINEER/Jr. CRESTRON PROG...            80
# 89                        Audio Visual Design Engineer            55
# 90          Professional Audio-Visual Systems Engineer            47
# 91                               Audio Visual Engineer            53
# 92                               Audio Visual Engineer            70
# 93                                  AV System Engineer            80
# 94                             Audio Visual Technician           41.6
# 95                                 AV Systems Engineer            67
# 96                                Systems Engineer- AV            67
# 97      Information Technology (IT) Support Specialist            36
# 98                             Audio/Visual Technician            35
# 99       IT Infrastructure Engineer - Washington, D.C.            93
# 100                        Audio Visual Field Engineer            44
# 101                            Audio Visual Technician            41
# 102  Audio/Video Journey Technician in IT Customer ...            65
# 103  Unified Comms/Audio Visual Engineer (AV Engine...            45
# 104  Entry-Level Engineering Cab (eCab) Systems & I...            84
# 105                            Audio Visual Technician          68.64
# 106                         Lead Audio Visual Engineer            74
# 107                          Sr. Audio-Visual Engineer           120
# 108                     Senior Audio Visual Technician          70.72
# 109                                      AV Technician            70
# 110                                AV Systems Engineer          54.08
# 111  Information Technology Help Desk Support - Up ...            85
# 112  AV Field Engineer/Audio/Video Technician/Audio...            35
# 113                                      AV Technician          37.44
# 114  Software Engineer C++ on Linux - (Jr, Sr, prin...            85
# 115                            Audio Visual Technician           62.4
# 116                                        AV Engineer           83.2
# 117                       Audio Visual Design Engineer            55
# 118         Professional Audio-Visual Systems Engineer            47
# 119                              Audio Visual Engineer            53
# 120                                AV Systems Engineer            67
# 121                            Audio Visual Technician           41.6
# 122                               Systems Engineer- AV            67
# 123                            Audio/Visual Technician            35
# 124  Audio/Video Journey Technician in IT Customer ...            65
# 125  Entry-Level Engineering Cab (eCab) Systems & I...            84
# 126                        IT Support Manager II (OAV)            79
# 127                            Audio Visual Technician            41
# 128   Audio Visual Technician II, Resort Entertainment            33
# 129                          IT Services Technician II            52
# 130     Information Technology (IT) Support Specialist            36
# 131                             AV/IT Support Engineer            45
# 132                            Audio Visual Technician          58.24
# 133                                AV Service Engineer            80
# 134                         Lead Audio Visual Engineer            74
# 135                          Sr. Audio-Visual Engineer           120
# 136                     Senior Audio Visual Technician          70.72
# 137                 Lead Audio Visual Field Technician            35
# 138                                AV Systems Engineer          54.08
# 139  Information Technology Help Desk Support - Up ...            85
# 140                                      AV Technician          37.44
# 141  AV Field Engineer/Audio/Video Technician/Audio...            35
# 142  Software Engineer C++ on Linux - (Jr, Sr, prin...            85
# 143                            Audio Visual Technician           62.4
# 144                                        AV Engineer           83.2
# 145                        Audio Visual Field Engineer            60
# 146                       Audio Visual Design Engineer            55
# 147                              Audio Visual Engineer            53
# 148                                        AV Engineer            63
# 149                            Audio/Visual Technician            35
# 150                                        AV Engineer            86
# 151  Audio/Video Journey Technician in IT Customer ...            65
# 152                             Field Support Engineer            66
# 153                    Audio Visual Support Technician            75
# 154  Entry-Level Engineering Cab (eCab) Systems & I...            84
# 155                            Audio Visual Technician            41
# 156                                        AV Engineer            63
# 157              Technical Architect - System Engineer            93
# 158                Audio Visual System Design Engineer            61
# 159                       Audio Visual Design Engineer            85
# 160                  (NY) Audio/Visual Design Engineer            50
# 161        Systems Engineer - Audio/Visual Integration            63
# 162                       Audio Visual Design Engineer            65
# 163                            Audio Visual Technician          58.24
# 164                 Audio Visual Design Sales Engineer            65
# 165                        Audio Visual Field Engineer           41.6
# 166     Pre-Sales Design Engineer, Audio Visual Remote            56
# 167                        Audio Visual Sales Engineer            70
# 168                          Sr. Audio-Visual Engineer           120
# 169                 Lead Audio Visual Field Technician            35
# 170  AV Field Engineer/Audio/Video Technician/Audio...            35
# 171  Information Technology Help Desk Support - Up ...            85
# 172                            Audio Visual Technician           62.4
# 173                                        AV Engineer           83.2
# 174  AUDIO VIDEO SYSTEMS ENGINEER/Jr. CRESTRON PROG...            80
# 175                              Audio Visual Engineer           62.4
# 176               Senior Audio Visual Systems Engineer            52
# 177              Sr. Network Technician-Audio Visual 1            35
# 178                                     Audio Engineer            47
# 179                       Audio Visual Engineer - Poly            54
# 180  Audio Visual Engineer - Information Technology...            60
# 181             Audio Visual Technician (Sr. Engineer)            56
# 182                Audio Visual System Design Engineer            61
# 183                       Audio Visual Design Engineer            85
# 184                  (NY) Audio/Visual Design Engineer            50
# 185        Systems Engineer - Audio/Visual Integration            63
# 186                       Audio Visual Design Engineer            65
# 187             Audio Visual Design Engineer/Estimator            85
# 188                         Lead Audio Visual Engineer            74
# 189                            Audio Visual Technician          58.24
# 190                        Audio Visual Field Engineer           41.6
# 191                 Audio Visual Design Sales Engineer            65
# 192     Pre-Sales Design Engineer, Audio Visual Remote            56
# 193                        Audio Visual Sales Engineer            70
# 194                          Sr. Audio-Visual Engineer           120
# 195                 Lead Audio Visual Field Technician            35
# 196  Information Technology Help Desk Support - Up ...            85
# 197  AV Field Engineer/Audio/Video Technician/Audio...            35
# 198                         Audio Visual (AV) Engineer          81.12
# 199                            Audio Visual Technician           62.4
# 200                                        AV Engineer           83.2
# 201  AUDIO VIDEO SYSTEMS ENGINEER/Jr. CRESTRON PROG...            80
# 202               Senior Audio Visual Systems Engineer            52
# 203             Audio Visual Technician (Sr. Engineer)            56
# 204                              Audio Visual Engineer           62.4
# 205  Audio Visual Engineer - Information Technology...            60
# 206                Audio Visual System Design Engineer            61
# 207                       Audio Visual Design Engineer            85
# 208                  (NY) Audio/Visual Design Engineer            50
# 209        Systems Engineer - Audio/Visual Integration            63
# 210                       Audio Visual Design Engineer            65
# 211                         Lead Audio Visual Engineer            74
# 212                            Audio Visual Technician          58.24
# 213                        Audio Visual Field Engineer           41.6
# 214                 Audio Visual Design Sales Engineer            65
# 215     Pre-Sales Design Engineer, Audio Visual Remote            56
# 216                        Audio Visual Sales Engineer            70
# 217                          Sr. Audio-Visual Engineer           120
# 218                 Lead Audio Visual Field Technician            35
# 219  AV Field Engineer/Audio/Video Technician/Audio...            35
# 220  Information Technology Help Desk Support - Up ...            85
# 221                         Audio Visual (AV) Engineer          81.12
# 222                            Audio Visual Technician           62.4
# 223  AUDIO VIDEO SYSTEMS ENGINEER/Jr. CRESTRON PROG...            80
# 224             Audio Visual Technician (Sr. Engineer)            56
# 225              Sr. Network Technician-Audio Visual 1            35
# 226                              Audio Visual Engineer           62.4
# 227  Audio Visual Engineer - Information Technology...            60
# 228               Senior Audio Visual Systems Engineer            52
# 229                Audio Visual System Design Engineer            61
# 230                       Audio Visual Design Engineer            85
# 231                  (NY) Audio/Visual Design Engineer            50
# 232        Systems Engineer - Audio/Visual Integration            63
# 233                       Audio Visual Design Engineer            65
# 234                         Lead Audio Visual Engineer            74
# 235                            Audio Visual Technician          58.24
# 236                        Audio Visual Field Engineer           41.6
# 237                 Audio Visual Design Sales Engineer            65
# 238     Pre-Sales Design Engineer, Audio Visual Remote            56
# 239                        Audio Visual Sales Engineer            70
# 240                          Sr. Audio-Visual Engineer           120
# 241                 Lead Audio Visual Field Technician            35
# 242  Information Technology Help Desk Support - Up ...            85
# 243                         Audio Visual (AV) Engineer          81.12
# 244                            Audio Visual Technician           62.4
# 245  AUDIO VIDEO SYSTEMS ENGINEER/Jr. CRESTRON PROG...            80
# 246  Audio Visual Engineer - Information Technology...            60
# 247             Audio Visual Technician (Sr. Engineer)            56
# 248              Sr. Network Technician-Audio Visual 1            35
# 249                              Audio Visual Engineer           62.4
# 250               Senior Audio Visual Systems Engineer            52
# 251               Senior Audio Visual Systems Engineer            52
# 252                Audio Visual System Design Engineer            61
# 253                       Audio Visual Design Engineer            85
# 254                  (NY) Audio/Visual Design Engineer            50
# 255        Systems Engineer - Audio/Visual Integration            63
# 256                       Audio Visual Design Engineer            65
# 257                         Lead Audio Visual Engineer            74
# 258                            Audio Visual Technician          58.24
# 259                 Audio Visual Design Sales Engineer            65
# 260     Pre-Sales Design Engineer, Audio Visual Remote            56
# 261                        Audio Visual Sales Engineer            70
# 262                          Sr. Audio-Visual Engineer           120
# 263                 Lead Audio Visual Field Technician            35
# 264  Information Technology Help Desk Support - Up ...            85
# 265                         Audio Visual (AV) Engineer          81.12
# 266                            Audio Visual Technician           62.4
# 267                                        AV Engineer           83.2
# 268  AUDIO VIDEO SYSTEMS ENGINEER/Jr. CRESTRON PROG...            80
# 269  Audio Visual Engineer - Information Technology...            60
# 270             Audio Visual Technician (Sr. Engineer)            56
# 271              Sr. Network Technician-Audio Visual 1            35
# 272                              Audio Visual Engineer           62.4
# 273               Senior Audio Visual Systems Engineer            52
# 274           Professional Audio-Visual Field Engineer            49
# 275                Audio Visual System Design Engineer            61
# 276                       Audio Visual Design Engineer            85
# 277                  (NY) Audio/Visual Design Engineer            50
# 278        Systems Engineer - Audio/Visual Integration            63
# 279                              Audio Visual Engineer            44
# 280                       Audio Visual Design Engineer            65
# 281                         Lead Audio Visual Engineer            74
# 282                            Audio Visual Technician          58.24
# 283                 Audio Visual Design Sales Engineer            65
# 284     Pre-Sales Design Engineer, Audio Visual Remote            56
# 285                        Audio Visual Sales Engineer            70
# 286                          Sr. Audio-Visual Engineer           120
# 287                 Lead Audio Visual Field Technician            35
# 288  AV Field Engineer/Audio/Video Technician/Audio...            35
# 289  Information Technology Help Desk Support - Up ...            85
# 290                         Audio Visual (AV) Engineer          81.12
# 291                            Audio Visual Technician           62.4
# 292                                        AV Engineer           83.2
# 293  AUDIO VIDEO SYSTEMS ENGINEER/Jr. CRESTRON PROG...            80
# 294  Audio Visual Engineer - Information Technology...            60
# 295                              Audio Visual Engineer           62.4
# 296             Audio Visual Technician (Sr. Engineer)            56
# 297               Senior Audio Visual Systems Engineer            52
# 298                Audio Visual System Design Engineer            61
# 299                       Audio Visual Design Engineer            85
# 300                  (NY) Audio/Visual Design Engineer            50
# 301                              Audio Visual Engineer            44
# 302        Systems Engineer - Audio/Visual Integration            63
# 303                       Audio Visual Design Engineer            65
# 304                         Lead Audio Visual Engineer            74
# 305                            Audio Visual Technician          58.24
# 306                 Audio Visual Design Sales Engineer            65
# 307     Pre-Sales Design Engineer, Audio Visual Remote            56
# 308                        Audio Visual Sales Engineer            70
# 309                          Sr. Audio-Visual Engineer           120
# 310                 Lead Audio Visual Field Technician            35
# 311                         Audio Visual (AV) Engineer          81.12
# 312                            Audio Visual Technician           62.4
# 313  AUDIO VIDEO SYSTEMS ENGINEER/Jr. CRESTRON PROG...            80
# 314  Audio Visual Engineer - Information Technology...            60
# 315             Audio Visual Technician (Sr. Engineer)            56
# 316               Senior Audio Visual Systems Engineer            52
# 317              Sr. Network Technician-Audio Visual 1            35
# 318                              Audio Visual Engineer           62.4
# 319            Senior Associate, Audio-Visual Engineer           100
# 320                       Audio Visual Engineer - Poly            54
# 321           Professional Audio-Visual Field Engineer            49
# 322                Audio Visual System Design Engineer            61
# 323                       Audio Visual Design Engineer            85
# 324                  (NY) Audio/Visual Design Engineer            50
# 325        Systems Engineer - Audio/Visual Integration            63
# 326                              Audio Visual Engineer            44
# 327                       Audio Visual Design Engineer            65
# 328                         Lead Audio Visual Engineer            74
# 329                            Audio Visual Technician          58.24
# 330                 Audio Visual Design Sales Engineer            65
# 331                        Audio Visual Field Engineer           41.6
# 332     Pre-Sales Design Engineer, Audio Visual Remote            56
# 333                        Audio Visual Sales Engineer            70
# 334                          Sr. Audio-Visual Engineer           120
# 335                     Senior Audio Visual Technician          70.72
# 336                 Lead Audio Visual Field Technician            35
# 337                         Audio Visual (AV) Engineer          81.12
# 338                            Audio Visual Technician           62.4
# 339  AUDIO VIDEO SYSTEMS ENGINEER/Jr. CRESTRON PROG...            80
# 340  Audio Visual Engineer - Information Technology...            60
# 341             Audio Visual Technician (Sr. Engineer)            56
# 342               Senior Audio Visual Systems Engineer            52
# 343                              Audio Visual Engineer           62.4
# 344              Sr. Network Technician-Audio Visual 1            35
# 345                Audio Visual System Design Engineer            61
# 346                       Audio Visual Design Engineer            85
# 347                  (NY) Audio/Visual Design Engineer            50
# 348                              Audio Visual Engineer            44
# 349        Systems Engineer - Audio/Visual Integration            63
# 350                       Audio Visual Design Engineer            65
# 351                            Audio Visual Technician          58.24
# 352                        Audio Visual Field Engineer           41.6
# 353                 Audio Visual Design Sales Engineer            65
# 354     Pre-Sales Design Engineer, Audio Visual Remote            56
# 355                        Audio Visual Sales Engineer            70
# 356                          Sr. Audio-Visual Engineer           120
# 357                 Lead Audio Visual Field Technician            35
# 358  Information Technology Help Desk Support - Up ...            85
# 359  AV Field Engineer/Audio/Video Technician/Audio...            35
# 360                         Audio Visual (AV) Engineer          81.12
# 361                            Audio Visual Technician           62.4
# 362  AUDIO VIDEO SYSTEMS ENGINEER/Jr. CRESTRON PROG...            80
# 363  Audio Visual Engineer - Information Technology...            60
# 364             Audio Visual Technician (Sr. Engineer)            56
# 365               Senior Audio Visual Systems Engineer            52
# 366                              Audio Visual Engineer           62.4
# 367              Sr. Network Technician-Audio Visual 1            35
# 368                                     Audio Engineer            47
# 369                Audio Visual System Design Engineer            61
# 370                       Audio Visual Design Engineer            85
# 371                  (NY) Audio/Visual Design Engineer            50
# 372                              Audio Visual Engineer            44
# 373        Systems Engineer - Audio/Visual Integration            63
# 374                       Audio Visual Design Engineer            65
# 375                            Audio Visual Technician          58.24
# 376                 Audio Visual Design Sales Engineer            65
# 377     Pre-Sales Design Engineer, Audio Visual Remote            56
# 378                        Audio Visual Sales Engineer            70
# 379                          Sr. Audio-Visual Engineer           120
# 380                 Lead Audio Visual Field Technician            35
# 381  Information Technology Help Desk Support - Up ...            85
# 382                         Audio Visual (AV) Engineer          81.12
# 383  AUDIO VIDEO SYSTEMS ENGINEER/Jr. CRESTRON PROG...            80
# 384  Audio Visual Engineer - Information Technology...            60
# 385             Audio Visual Technician (Sr. Engineer)            56
# 386               Senior Audio Visual Systems Engineer            52
# 387              Sr. Network Technician-Audio Visual 1            35
# 388                              Audio Visual Engineer           62.4
# 389                                     Audio Engineer            47
# 390           Professional Audio-Visual Field Engineer            49
# 391               Senior Audio-Visual Systems Engineer            50
# 392                Audio Visual System Design Engineer            61
# 393                       Audio Visual Design Engineer            85
# 394                  (NY) Audio/Visual Design Engineer            50
# 395        Systems Engineer - Audio/Visual Integration            63
# 396                              Audio Visual Engineer            44
# 397                       Audio Visual Design Engineer            65
# 398                            Audio Visual Technician          58.24
# 399                 Audio Visual Design Sales Engineer            65
# 400     Pre-Sales Design Engineer, Audio Visual Remote            56
# 401                        Audio Visual Sales Engineer            70
# 402                          Sr. Audio-Visual Engineer           120
# 403                 Lead Audio Visual Field Technician            35
# 404                         Audio Visual (AV) Engineer          81.12
# 405  AUDIO VIDEO SYSTEMS ENGINEER/Jr. CRESTRON PROG...            80
# 406  Audio Visual Engineer - Information Technology...            60
# 407             Audio Visual Technician (Sr. Engineer)            56
# 408               Senior Audio Visual Systems Engineer            52
# 409              Sr. Network Technician-Audio Visual 1            35
# 410           Professional Audio-Visual Field Engineer            49
# 411                                     Audio Engineer            47
# 412                              Audio Visual Engineer           62.4
# 413                       Audio Visual Engineer - Poly            54
# 414            Senior Associate, Audio-Visual Engineer           100
# 415                       Audio Visual Design Engineer            55
# 416                Audio Visual System Design Engineer            61
# 417                       Audio Visual Design Engineer            85
# 418                  (NY) Audio/Visual Design Engineer            50
# 419                              Audio Visual Engineer            44
# 420        Systems Engineer - Audio/Visual Integration            63
# 421                            Audio Visual Technician          58.24
# 422                 Audio Visual Design Sales Engineer            65
# 423     Pre-Sales Design Engineer, Audio Visual Remote            56
# 424                      Audio Visual Systems Engineer            70
# 425                        Audio Visual Sales Engineer            70
# 426                 Lead Audio Visual Field Technician            35
# 427                         Audio Visual (AV) Engineer          81.12
# 428  AUDIO VIDEO SYSTEMS ENGINEER/Jr. CRESTRON PROG...            80
# 429  Audio Visual Engineer - Information Technology...            60
# 430             Audio Visual Technician (Sr. Engineer)            56
# 431               Senior Audio Visual Systems Engineer            52
# 432                              Audio Visual Engineer           62.4
# 433           Professional Audio-Visual Field Engineer            49
# 434                                     Audio Engineer            47
# 435                       Audio Visual Engineer - Poly            54
# 436              Sr. Network Technician-Audio Visual 1            35
# 437               Senior Audio-Visual Systems Engineer            50
# 438            Senior Associate, Audio-Visual Engineer           100
# 439                       Audio Visual Design Engineer            55
# 440                Audio Visual System Design Engineer            61
# 441                       Audio Visual Design Engineer            85
# 442                  (NY) Audio/Visual Design Engineer            50
# 443        Systems Engineer - Audio/Visual Integration            63
# 444        Systems Engineer - Audio/Visual Integration            63
# 445                            Audio Visual Technician          58.24
# 446                 Audio Visual Design Sales Engineer            65
# 447     Pre-Sales Design Engineer, Audio Visual Remote            56
# 448                        Audio Visual Sales Engineer            70
# 449                      Audio Visual Systems Engineer            70
# 450                 Lead Audio Visual Field Technician            35
# 451  AUDIO VIDEO SYSTEMS ENGINEER/Jr. CRESTRON PROG...            80
# 452  Audio Visual Engineer - Information Technology...            60
# 453                       Audio Visual Design Engineer            55
# 454             Audio Visual Technician (Sr. Engineer)            56
# 455               Senior Audio Visual Systems Engineer            52
# 456           Professional Audio-Visual Field Engineer            49
# 457            Senior Associate, Audio-Visual Engineer           100
# 458              Sr. Network Technician-Audio Visual 1            35
# 459                                     Audio Engineer            47
# 460                       Audio Visual Engineer - Poly            54
# 461                              Audio Visual Engineer           62.4
# 462               Senior Audio-Visual Systems Engineer            50
# 463                Audio Visual System Design Engineer            61
# 464                       Audio Visual Design Engineer            85
# 465                  (NY) Audio/Visual Design Engineer            50
# 466        Systems Engineer - Audio/Visual Integration            63
# 467                       Audio Visual Design Engineer            65
# 468                            Audio Visual Technician          58.24
# 469     Pre-Sales Design Engineer, Audio Visual Remote            56
# 470                      Audio Visual Systems Engineer            70
# 471                        Audio Visual Sales Engineer            70
# 472                 Lead Audio Visual Field Technician            35
# 473  AUDIO VIDEO SYSTEMS ENGINEER/Jr. CRESTRON PROG...            80
# 474  Audio Visual Engineer - Information Technology...            60
# 475                       Audio Visual Design Engineer            55
# 476             Audio Visual Technician (Sr. Engineer)            56
# 477               Senior Audio Visual Systems Engineer            52
# 478              Sr. Network Technician-Audio Visual 1            35
# 479                                     Audio Engineer            47
# 480           Professional Audio-Visual Field Engineer            49
# 481                       Audio Visual Engineer - Poly            54
# 482               Senior Audio-Visual Systems Engineer            50
# 483         Audio Visual Engineer Technical Specialist            97
# 484                              Audio Visual Engineer           62.4
# 485            Senior Associate, Audio-Visual Engineer           100
# 486                        Audio Visual Sales Engineer            80
# 487        Systems Engineer - Audio/Visual Integration            63
# 488     Pre-Sales Design Engineer, Audio Visual Remote            56
# 489                        Audio Visual Sales Engineer            70
# 490                      Audio Visual Systems Engineer            70
# 491                 Lead Audio Visual Field Technician            35
# 492  AUDIO VIDEO SYSTEMS ENGINEER/Jr. CRESTRON PROG...            80
# 493  Audio Visual Engineer - Information Technology...            60
# 494                       Audio Visual Design Engineer            55
# 495             Audio Visual Technician (Sr. Engineer)            56
# 496               Senior Audio Visual Systems Engineer            52
# 497              Sr. Network Technician-Audio Visual 1            35
# 498                       Audio Visual Engineer - Poly            54
# 499                                     Audio Engineer            47
# 500           Professional Audio-Visual Field Engineer            49
# 501         Audio Visual Engineer Technical Specialist            97
# 502                              Audio Visual Engineer           62.4
# 503               Senior Audio-Visual Systems Engineer            50
# 504            Senior Associate, Audio-Visual Engineer           100
# 505                              Audio Visual Engineer            44
# 506     Audio Visual Technician (AV) - Santa Clara, CA            44
# 507                Audio Visual Collaboration Engineer            57
# 508                        Audio Visual Sales Engineer            80
# 509                              Audio Visual Engineer            70
# 510                Audio Visual System Design Engineer            61
# 511                  (NY) Audio/Visual Design Engineer            50
# 512        Systems Engineer - Audio/Visual Integration            63
# 513                       Audio Visual Design Engineer            65
# 514     Pre-Sales Design Engineer, Audio Visual Remote            56
# 515                      Audio Visual Systems Engineer            70
# 516                        Audio Visual Sales Engineer            70
# 517                 Lead Audio Visual Field Technician            35
# 518  AV Field Engineer/Audio/Video Technician/Audio...            35
# 519  AUDIO VIDEO SYSTEMS ENGINEER/Jr. CRESTRON PROG...            80
# 520  Audio Visual Engineer - Information Technology...            60
# 521                       Audio Visual Design Engineer            55
# 522            Senior Associate, Audio-Visual Engineer           100
# 523             Audio Visual Technician (Sr. Engineer)            56
# 524               Senior Audio Visual Systems Engineer            52
# 525                       Audio Visual Engineer - Poly            54
# 526              Sr. Network Technician-Audio Visual 1            35
# 527           Professional Audio-Visual Field Engineer            49
# 528         Audio Visual Engineer Technical Specialist            97
# 529                                     Audio Engineer            47
# 530     Audio Visual Technician (AV) - Santa Clara, CA            44
# 531               Senior Audio-Visual Systems Engineer            50
# 532                              Audio Visual Engineer           62.4
# 533                              Audio Visual Engineer            44
# 534                Audio Visual System Design Engineer            61
# 535                  (NY) Audio/Visual Design Engineer            50
# 536        Systems Engineer - Audio/Visual Integration            63
# 537                       Audio Visual Design Engineer            65
# 538     Pre-Sales Design Engineer, Audio Visual Remote            56
# 539                        Audio Visual Sales Engineer            70
# 540                      Audio Visual Systems Engineer            70
# 541                 Lead Audio Visual Field Technician            35
# 542  AV Field Engineer/Audio/Video Technician/Audio...            35
# 543                         Audio Visual (AV) Engineer          81.12
# 544  AUDIO VIDEO SYSTEMS ENGINEER/Jr. CRESTRON PROG...            80
# 545  Audio Visual Engineer - Information Technology...            60
# 546                       Audio Visual Design Engineer            55
# 547            Senior Associate, Audio-Visual Engineer           100
# 548             Audio Visual Technician (Sr. Engineer)            56
# 549               Senior Audio Visual Systems Engineer            52
# 550                       Audio Visual Engineer - Poly            54
# 551              Sr. Network Technician-Audio Visual 1            35
# 552                              Audio Visual Engineer           62.4
# 553         Audio Visual Engineer Technical Specialist            97
# 554                                     Audio Engineer            47
# 555           Professional Audio-Visual Field Engineer            49
# 556               Senior Audio-Visual Systems Engineer            50
# 557               Senior Audio-Visual Systems Engineer            50
# 558                  (NY) Audio/Visual Design Engineer            50
# 559                              Audio Visual Engineer            44
# 560        Systems Engineer - Audio/Visual Integration            63
# 561     Pre-Sales Design Engineer, Audio Visual Remote            56
# 562                        Audio Visual Sales Engineer            70
# 563                      Audio Visual Systems Engineer            70
# 564                 Lead Audio Visual Field Technician            35
# 565  AV Field Engineer/Audio/Video Technician/Audio...            35
# 566                         Audio Visual (AV) Engineer          81.12
# 567                            Audio Visual Technician           62.4
# 568  AUDIO VIDEO SYSTEMS ENGINEER/Jr. CRESTRON PROG...            80
# 569  Audio Visual Engineer - Information Technology...            60
# 570                       Audio Visual Design Engineer            55
# 571            Senior Associate, Audio-Visual Engineer           100
# 572             Audio Visual Technician (Sr. Engineer)            56
# 573               Senior Audio Visual Systems Engineer            52
# 574                       Audio Visual Engineer - Poly            54
# 575              Sr. Network Technician-Audio Visual 1            35
# 576         Audio Visual Engineer Technical Specialist            97
# 577                              Audio Visual Engineer           62.4
# 578           Professional Audio-Visual Field Engineer            49
# 579                                     Audio Engineer            47
# 580                                     Audio Engineer            47
# 581                       Audio Visual Design Engineer            85
# 582        Systems Engineer - Audio/Visual Integration            63
# 583     Pre-Sales Design Engineer, Audio Visual Remote            56
# 584                        Audio Visual Sales Engineer            70
# 585                      Audio Visual Systems Engineer            70
# 586                 Lead Audio Visual Field Technician            35
# 587                         Audio Visual (AV) Engineer          81.12
# 588  AUDIO VIDEO SYSTEMS ENGINEER/Jr. CRESTRON PROG...            80
# 589  Audio Visual Engineer - Information Technology...            60
# 590                       Audio Visual Design Engineer            55
# 591            Senior Associate, Audio-Visual Engineer           100
# 592             Audio Visual Technician (Sr. Engineer)            56
# 593               Senior Audio Visual Systems Engineer            52
# 594                       Audio Visual Engineer - Poly            54
# 595              Sr. Network Technician-Audio Visual 1            35
# 596         Audio Visual Engineer Technical Specialist            97
# 597                              Audio Visual Engineer           62.4
# 598                                     Audio Engineer            47
# 599                              Audio Visual Engineer            44
# 600           Professional Audio-Visual Field Engineer            49
# 601                        Audio Visual Sales Engineer            80
# 602                        Audio Visual Sales Engineer            80
# 603           Professional Audio-Visual Field Engineer            49
# 604                       Audio Visual Design Engineer            44
# 605                       Audio Visual Design Engineer            85
# 606                  (NY) Audio/Visual Design Engineer            50
# 607        Systems Engineer - Audio/Visual Integration            63
# 608                 Audio Visual Design Sales Engineer            65
# 609                 Audio Visual Design Sales Engineer            65
# 610     Pre-Sales Design Engineer, Audio Visual Remote            56
# 611                        Audio Visual Sales Engineer            70
# 612                      Audio Visual Systems Engineer            70
# 613                 Lead Audio Visual Field Technician            35
# 614                         Audio Visual (AV) Engineer          81.12
# 615                         Audio Visual (AV) Engineer          81.12
# 616  AUDIO VIDEO SYSTEMS ENGINEER/Jr. CRESTRON PROG...            80
# 617  Audio Visual Engineer - Information Technology...            60
# 618            Senior Associate, Audio-Visual Engineer           100
# 619                       Audio Visual Design Engineer            55
# 620             Audio Visual Technician (Sr. Engineer)            56
# 621              Sr. Network Technician-Audio Visual 1            35
# 622               Senior Audio Visual Systems Engineer            52
# 623                       Audio Visual Engineer - Poly            54
# 624         Audio Visual Engineer Technical Specialist            97
# 625         Audio Visual Engineer Technical Specialist            97
# 626                              Audio Visual Engineer            44
# 627                        Audio Visual Sales Engineer            80
# 628                                     Audio Engineer            47
# 629           Professional Audio-Visual Field Engineer            49
# 630                       Audio Visual Design Engineer            44
# 631                       Audio Visual Design Engineer            85
# 632                  (NY) Audio/Visual Design Engineer            50
# 633        Systems Engineer - Audio/Visual Integration            63
# 634                 Audio Visual Design Sales Engineer            65
# 635     Pre-Sales Design Engineer, Audio Visual Remote            56
# 636                      Audio Visual Systems Engineer            70
# 637                        Audio Visual Sales Engineer            70
# 638                        Audio Visual Sales Engineer            70
# 639  AV Field Engineer/Audio/Video Technician/Audio...            35
# 640                         Audio Visual (AV) Engineer          81.12
# 641                            Audio Visual Technician           62.4
# 642  AUDIO VIDEO SYSTEMS ENGINEER/Jr. CRESTRON PROG...            80
# 643              Sr. Network Technician-Audio Visual 1            35
# 644  Audio Visual Engineer - Information Technology...            60
# 645            Senior Associate, Audio-Visual Engineer           100
# 646                       Audio Visual Design Engineer            55
# 647                       Audio Visual Engineer - Poly            54
# 648             Audio Visual Technician (Sr. Engineer)            56
# 649               Senior Audio Visual Systems Engineer            52
# 650           Professional Audio-Visual Field Engineer            49
# 651         Audio Visual Engineer Technical Specialist            97
# 652                              Audio Visual Engineer            44
# 653         Audio Visual Engineer Technical Specialist            97
# 654                              Audio Visual Engineer            44
# 655           Professional Audio-Visual Field Engineer            49
# ...
# 515          New York      NY                  6.0
# 516            Remote  Remote                  NaN
# 517          New York      NY                 14.0
# 518           Baytown      TX                  NaN
# 519           Olympia      WA                133.0
# 520     San Francisco      CA                 60.0
# 521          Plymouth      MN                  NaN
# 522            Remote  Remote                  NaN
# 523            Irvine      CA                 64.0
# 524             Boise      ID                 46.0
# 525            Camden      NJ                136.0
# 526  Saint Petersburg      FL                133.0
# 527          New York      NY                  NaN
# 528          Honolulu      HI                  5.0
# 529        Washington      DC                 46.0
# 530       Santa Clara      CA                 47.0
# 531         Fairfield      CT                 59.0
# 532  Farmington Hills      MI                 24.0
# 533       Bala Cynwyd      PA                 35.0
# 534            Denver      CO                  NaN
# 535          New York      NY                 62.0
# 536          New York      NY                 76.0
# 537           Gilbert      AZ                  NaN
# 538           Roswell      GA                137.0
# 539            Remote  Remote                  NaN
# 540          New York      NY                  6.0
# 541          New York      NY                 14.0
# 542           Baytown      TX                  NaN
# 543        Richardson      TX                 74.0
# 544           Olympia      WA                133.0
# 545     San Francisco      CA                 60.0
# 546          Plymouth      MN                  NaN
# 547            Remote  Remote                  NaN
# 548            Irvine      CA                 64.0
# 549             Boise      ID                 46.0
# 550            Camden      NJ                136.0
# 551  Saint Petersburg      FL                133.0
# 552  Farmington Hills      MI                 24.0
# 553          Honolulu      HI                  5.0
# 554        Washington      DC                 46.0
# 555          New York      NY                  NaN
# 556         Fairfield      CT                 59.0
# 557         Fairfield      CT                 59.0
# 558          New York      NY                 62.0
# 559         Deer Park      NY                  NaN
# 560          New York      NY                 76.0
# 561           Roswell      GA                137.0
# 562            Remote  Remote                  NaN
# 563          New York      NY                  6.0
# 564          New York      NY                 14.0
# 565           Baytown      TX                  NaN
# 566        Richardson      TX                 74.0
# 567          New York      NY                  NaN
# 568           Olympia      WA                133.0
# 569     San Francisco      CA                 60.0
# 570          Plymouth      MN                  NaN
# 571            Remote  Remote                  NaN
# 572            Irvine      CA                 64.0
# 573             Boise      ID                 46.0
# 574            Camden      NJ                136.0
# 575  Saint Petersburg      FL                133.0
# 576          Honolulu      HI                  5.0
# 577  Farmington Hills      MI                 24.0
# 578          New York      NY                  NaN
# 579        Washington      DC                 46.0
# 580        Washington      DC                 46.0
# 581   West Palm Beach      FL                  8.0
# 582          New York      NY                 76.0
# 583           Roswell      GA                137.0
# 584            Remote  Remote                  NaN
# 585          New York      NY                  6.0
# 586          New York      NY                 14.0
# 587        Richardson      TX                 74.0
# 588           Olympia      WA                133.0
# 589     San Francisco      CA                 60.0
# 590          Plymouth      MN                  NaN
# 591            Remote  Remote                  NaN
# 592            Irvine      CA                 64.0
# 593             Boise      ID                 46.0
# 594            Camden      NJ                136.0
# 595  Saint Petersburg      FL                133.0
# 596          Honolulu      HI                  5.0
# 597  Farmington Hills      MI                 24.0
# 598        Washington      DC                 46.0
# 599       Bala Cynwyd      PA                 35.0
# 600          New York      NY                  NaN
# 601           Clifton      NJ                  NaN
# 602           Clifton      NJ                  NaN
# 603          New York      NY                  NaN
# 604           Atlanta      GA                 34.0
# 605   West Palm Beach      FL                  8.0
# 606          New York      NY                 62.0
# 607          New York      NY                 76.0
# 608          New York      NY                  NaN
# 609          New York      NY                  NaN
# 610           Roswell      GA                137.0
# 611            Remote  Remote                  NaN
# 612          New York      NY                  6.0
# 613          New York      NY                 14.0
# 614        Richardson      TX                 74.0
# 615        Richardson      TX                 74.0
# 616           Olympia      WA                133.0
# 617     San Francisco      CA                 60.0
# 618            Remote  Remote                  NaN
# 619          Plymouth      MN                  NaN
# 620            Irvine      CA                 64.0
# 621  Saint Petersburg      FL                133.0
# 622             Boise      ID                 46.0
# 623            Camden      NJ                136.0
# 624          Honolulu      HI                  5.0
# 625          Honolulu      HI                  5.0
# 626       Bala Cynwyd      PA                 35.0
# 627           Clifton      NJ                  NaN
# 628        Washington      DC                 46.0
# 629          New York      NY                  NaN
# 630           Atlanta      GA                 34.0
# 631   West Palm Beach      FL                  8.0
# 632          New York      NY                 62.0
# 633          New York      NY                 76.0
# 634          New York      NY                  NaN
# 635           Roswell      GA                137.0
# 636          New York      NY                  6.0
# 637            Remote  Remote                  NaN
# 638            Remote  Remote                  NaN
# 639           Baytown      TX                  NaN
# 640        Richardson      TX                 74.0
# 641          New York      NY                  NaN
# 642           Olympia      WA                133.0
# 643  Saint Petersburg      FL                133.0
# 644     San Francisco      CA                 60.0
# 645            Remote  Remote                  NaN
# 646          Plymouth      MN                  NaN
# 647            Camden      NJ                136.0
# 648            Irvine      CA                 64.0
# 649             Boise      ID                 46.0
# 650          New York      NY                  NaN
# 651          Honolulu      HI                  5.0
# 652       Bala Cynwyd      PA                 35.0
# 653          Honolulu      HI                  5.0
# 654       Bala Cynwyd      PA                 35.0
# 655          New York      NY                  NaN
# 656   West Palm Beach      FL                  8.0
# 657          New York      NY                 62.0
# 658         Deer Park      NY                  NaN
# 659          New York      NY                 76.0
# 660          New York      NY                  NaN
# 661          New York      NY                  NaN
# 662           Roswell      GA                137.0
# 663            Remote  Remote                  NaN
# 664          New York      NY                  6.0
# 665           Baytown      TX                  NaN
# 666          New York      NY                  NaN
# 667           Baytown      TX                  NaN
# 668          New York      NY                  NaN
# 669           Olympia      WA                133.0
# 670     San Francisco      CA                 60.0
# 671  Saint Petersburg      FL                133.0
# 672          Plymouth      MN                  NaN
# 673            Remote  Remote                  NaN
# 674            Camden      NJ                136.0
# 675            Irvine      CA                 64.0
# 676             Boise      ID                 46.0
# 677  Farmington Hills      MI                 24.0
# 678          Honolulu      HI                  5.0
# 679       Bala Cynwyd      PA                 35.0
# 680          New York      NY                  NaN
# 681          New York      NY                 62.0
# 682          New York      NY                 62.0
# 683          New York      NY                 76.0
# 684         Deer Park      NY                  NaN
# 685          New York      NY                 76.0
# 686          New York      NY                  NaN
# 687           Roswell      GA                137.0
# 688            Remote  Remote                  NaN
# 689          Pasadena      CA                  NaN
# 690           Baytown      TX                  NaN
# 691          New York      NY                  NaN
# 692           Olympia      WA                133.0
# 693     San Francisco      CA                 60.0
# 694  Saint Petersburg      FL                133.0
# 695            Remote  Remote                  NaN
# 696          Plymouth      MN                  NaN
# 697            Camden      NJ                136.0
# 698            Irvine      CA                 64.0
# 699             Boise      ID                 46.0
# 700          Honolulu      HI                  5.0
# 701  Farmington Hills      MI                 24.0
# 702       Bala Cynwyd      PA                 35.0
# 703          New York      NY                  NaN
# 704            Remote  Remote                  NaN
# 705           Clifton      NJ                  NaN
# 706          New York      NY                 62.0
# 707         Deer Park      NY                  NaN
# 708          New York      NY                 76.0
# 709          New York      NY                  NaN
# 710           Roswell      GA                137.0
# 711            Remote  Remote                  NaN
# 712          New York      NY                  6.0
# 713           Roswell      GA                137.0
# 714           Baytown      TX                  NaN
# 715        Richardson      TX                 74.0
# 716     San Francisco      CA                 60.0
# 717           Olympia      WA                133.0
# 718            Remote  Remote                  NaN
# 719  Saint Petersburg      FL                133.0
# 720            Camden      NJ                136.0
# 721          Plymouth      MN                  NaN
# 722            Irvine      CA                 64.0
# 723             Boise      ID                 46.0
# 724          Honolulu      HI                  5.0
# 725          New York      NY                  NaN
# 726  Farmington Hills      MI                 24.0
# 727       Bala Cynwyd      PA                 35.0
# 728  Farmington Hills      MI                 24.0
# 729          New York      NY                  NaN
# 730       Bala Cynwyd      PA                 35.0
# 731          New York      NY                 62.0
# 732          New York      NY                 62.0
# 733      Pennsylvania      PA                  NaN
# 734           Roswell      GA                137.0
# 735          New York      NY                 76.0
# 736          New York      NY                  6.0
# 737      Pennsylvania      PA                  NaN
# 738        Richardson      TX                 74.0
# 739           Roswell      GA                137.0
# 740            Remote  Remote                  NaN
# 741          New York      NY                  6.0
# 742            Remote  Remote                  NaN
# 743        Richardson      TX                 74.0
# 744             Boise      ID                 46.0
# 745           Olympia      WA                133.0
# 746     San Francisco      CA                 60.0
# 747  Saint Petersburg      FL                133.0
# 748            Remote  Remote                  NaN
# 749          Plymouth      MN                  NaN
# 750            Camden      NJ                136.0
# 751            Irvine      CA                 64.0
# 752             Boise      ID                 46.0
# 753          Honolulu      HI                  5.0
# 754  Farmington Hills      MI                 24.0
# 755          New York      NY                  NaN
# 756       Bala Cynwyd      PA                 35.0
# 757          New York      NY                 62.0
# 758          New York      NY                 76.0
# 759      Pennsylvania      PA                  NaN
# 760           Roswell      GA                137.0
# 761            Remote  Remote                  NaN
# 762          New York      NY                  6.0
# 763        Richardson      TX                 74.0
# 764     San Francisco      CA                 60.0
# 765           Olympia      WA                133.0
# 766            Camden      NJ                136.0
# 767  Saint Petersburg      FL                133.0
# 768            Remote  Remote                  NaN
# 769            Irvine      CA                 64.0
# 770             Boise      ID                 46.0
# 771  Farmington Hills      MI                 24.0
# 772          Honolulu      HI                  5.0
# 773          New York      NY                  NaN
# 774       Bala Cynwyd      PA                 35.0
# 775      Philadelphia      PA                  NaN
# 776         Fairfield      CT                 59.0
# 777       Santa Clara      CA                 47.0
# 778           Atlanta      GA                 34.0
# 779         Fairfield      CT                 59.0
# 780       Santa Clara      CA                 47.0
# 781           Atlanta      GA                 34.0
# 782          New York      NY                 62.0
# 783          New York      NY                 76.0
# 784          New York      NY                 76.0
# 785      Pennsylvania      PA                  NaN
# 786           Roswell      GA                137.0
# 787            Remote  Remote                  NaN
# 788          New York      NY                  6.0
# 789          New York      NY                 14.0
# 790        Richardson      TX                 74.0
# 791        Richardson      TX                 74.0
# 792           Baytown      TX                  NaN
# 793     San Francisco      CA                 60.0
# 794  Saint Petersburg      FL                133.0
# 795            Camden      NJ                136.0
# 796           Olympia      WA                133.0
# 797            Remote  Remote                  NaN
# 798            Irvine      CA                 64.0
# 799             Boise      ID                 46.0
# 800          Honolulu      HI                  5.0
# 801  Farmington Hills      MI                 24.0
# 802          New York      NY                  NaN
# 803       Bala Cynwyd      PA                 35.0
# 804      Philadelphia      PA                  NaN
# 805           Atlanta      GA                 34.0
# 806       Santa Clara      CA                 47.0
# 807           Atlanta      GA                 34.0
# 808          New York      NY                 62.0
# 809          New York      NY                 76.0
# 810      Pennsylvania      PA                  NaN
# 811      Pennsylvania      PA                  NaN
# 812           Roswell      GA                137.0
# 813            Remote  Remote                  NaN
# 814          New York      NY                  6.0
# 815          New York      NY                 14.0

# %%
# Group jobs under archetypes (Junior v senior, analyst v business analyst)
pd.set_option('display.max_rows', None)
data_cleaned["Job Title"].value_counts() # count instances of job titles occuring
# Out:
# Audio Visual Engineer                                                      62
# Audio Visual Design Engineer                                               61
# Audio Visual Technician                                                    44
# Audio Visual Sales Engineer                                                38
# Systems Engineer - Audio/Visual Integration                                32
# Pre-Sales Design Engineer, Audio Visual Remote                             31
# Senior Audio Visual Systems Engineer                                       30
# (NY) Audio/Visual Design Engineer                                          29
# Audio Visual Technician (Sr. Engineer)                                     29
# AUDIO VIDEO SYSTEMS ENGINEER/Jr. CRESTRON PROGRAMMER                       29
# Audio Visual Engineer - Information Technology Consultant - Career         28
# Sr. Network Technician-Audio Visual 1                                      26
# Audio Visual (AV) Engineer                                                 24
# Professional Audio-Visual Field Engineer                                   23
# Lead Audio Visual Field Technician                                         23
# Audio Visual Design Sales Engineer                                         21
# Senior Associate, Audio-Visual Engineer                                    20
# Audio Visual Engineer - Poly                                               20
# Sr. Audio-Visual Engineer                                                  19
# AV Field Engineer/Audio/Video Technician/Audio Visual Specialist           19
# Audio Visual Field Engineer                                                18
# Audio Visual System Design Engineer                                        17
# Audio Visual Engineer Technical Specialist                                 17
# Audio Engineer                                                             15
# Audio Visual Systems Engineer                                              15
# Information Technology Help Desk Support - Up to $95k                      13
# Lead Audio Visual Engineer                                                 11
# Senior Audio-Visual Systems Engineer                                       11
# AV Engineer                                                                10
# AV Systems Engineer                                                         5
# Audio Visual Technician (AV) - Santa Clara, CA                              5
# AV Technician                                                               4
# Technical Sound Designer                                                    3
# Professional Audio-Visual Systems Engineer                                  3
# Audio/Video Journey Technician in IT Customer Support                       3
# Entry-Level Engineering Cab (eCab) Systems & Integration Engineers          3
# Senior Audio Visual Technician                                              3
# Audio/Visual Technician                                                     3
# Audio Visual Collaboration Engineer                                         2
# Audio Visual Fabrication Engineer                                           2
# Information Technology (IT) Support Specialist                              2
# Systems Engineer- AV                                                        2
# Audio Visual Systems Design Engineer                                        2
# Coordinator and Audio-Video Engineer                                        2
# Onsite Audio Visual Engineer                                                2
# Audio-Visual Engineer Tier III                                              2
# Software Engineer C++ on Linux - (Jr, Sr, principal, architect)             2
# AV Service Engineer                                                         2
# Audio Visual Design Engineer/Estimator                                      2
# IT Support Manager II (OAV)                                                 1
# Audio Visual Support Technician                                             1
# Field Support Engineer                                                      1
# Technical Architect - System Engineer                                       1
# IT Infrastructure Engineer - Washington, D.C.                               1
# Audio Visual Technician II, Resort Entertainment                            1
# Unified Comms/Audio Visual Engineer (AV Engineering)                        1
# IT Services Technician II                                                   1
# AV/IT Support Engineer                                                      1
# Audio Visual Systems Field Engineer                                         1
# Sneaky Big Studios - Audio Engineer                                         1
# Technical Design Engineer - Audio Visual - $70k and Up                      1
# AV System Engineer                                                          1
# Audio Visual (AV) Post Engineer                                             1
# UC - Audio Visual/Multimedia Engineer Level 2                               1
# Audio Visual Fabrication Engineer – Senior                                  1
# Audio Visual Project Engineer                                               1
# Audio-Visual Engineer                                                       1
# Senior Service Engineer - Audio-Visual System Engineer                      1
# Audio Visual Production Engineer                                            1
# Audio / Visual Support Specialist                                           1
# Senior Audio Visual Design Engineer                                         1
# R&D Test Engineer                                                           1
# Audio Visual Technicians Sought                                             1
# Audio & Visual Engineer                                                     1
# Freelance Audio Engineer I                                                  1
# A/V Project Manager / Systems Design Engineer - Low Voltage Audio Video     1
# Name: Job Title, dtype: int64

# %% [markdown]
# We can see from above that there are already some redundancies due to small changes in the titles (eg Sr. Data Analyst ). Let's group the jobs together with a function that searches the titles and combines everything under similar banners (manager, analyst, specialist, etc). Ken Jee created some nice functions that will serve us well, so if you wish to see more here is the link: https://youtu.be/QWgg4w1SpJ8.

# %%
#define functions to bin jobs into groups
def title_condencer(title):
    if 'engineer' in title.lower():
        return 'engineer'
    elif 'technician' in title.lower():
        return 'technician'
    else:
        return 'Unbinned'

#identify if there is a seniority or level flag
def seniority(title):
    if 'sr' in title.lower() or 'senior' in title.lower() or 'sr.' in title.lower() or 'lead' in title.lower() or 'prinicpal' in title.lower() or 'iii' in title.lower():
        return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower() or 'junior' in title.lower():
        return 'junior'
    else:
        return 'na'

# %%
#Check binning
data_cleaned['Job Title'] = data_cleaned['Job Title'].values.astype(str)
data_cleaned['Title Grouping'] = data_cleaned['Job Title'].apply(title_condencer)
data_cleaned['Title Grouping'].value_counts()
# Out:
# engineer      681
# technician    115
# Unbinned       20
# Name: Title Grouping, dtype: int64

# %%
#check seniority level
data_cleaned['Seniority Level'] = data_cleaned['Job Title'].apply(seniority)
data_cleaned['Seniority Level'].value_counts()
# Out:
# na        608
# senior    179
# junior     29
# Name: Seniority Level, dtype: int64

# %%
#input the filename you wish to save the information as
file = r"C:\Users\Tineash\Projects\Glassdoor_webscraper\Data\AV_eng_data_cleaned.csv" #place the filepath between the quotes

data_cleaned.to_csv(file, index = False)

# %%
# check for string answers for Ownership column - to do

# %%
# Replace string "unknown/Non-applicable" in revenue with NaN - to do

# %%
# remove texts from revenue and convert revenue range to an average revenue as an int/float
